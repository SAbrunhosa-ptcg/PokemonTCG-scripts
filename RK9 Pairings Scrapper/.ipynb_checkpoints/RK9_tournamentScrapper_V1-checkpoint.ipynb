# %%
import requests
import re
from bs4 import BeautifulSoup
import json
import pandas as pd
import numpy as np

# %%
### CLASSES ###

# class to hold individual player information
class Player:
    def __init__(self, player_id, name, link, classification):
        self.id = player_id # unique ID, in case it is useful later (not pokemonID)
        self.name = name

        self.decklist_link = link
        self.classification = classification
        self.CP = 0
        self.Day2 = False

        self.round_data = {} # {'R1': ['Jane Doe', 'W'], 'R2': ['John Doe', 'L'], ...}
        self.score = [0, 0, 0] # W, L, T
        self.points = 0
        
        self.round_data = {'R1': ['Jane Doe', 'W']}
        
        self.decklist = []
        self.pokemonlist = []
        self.archetype = 'Mew VMAX'
        self.variant = 'Lost Kyogre' # RIP

# %%
### FUNCTIONS ###

# get soup from URL
def GetWebpage(URL):
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, "html.parser")
    return soup

# scrap tournament data
def GetPlayerData(tournament_soup):  
    find_list = tournament_soup.find_all('tr') # get all players from the player table (i.e. table rows)
    find_list.pop(0) # pop header row
    
    # counters for number of players in each division
    master_counter = 0
    senior_counter = 0 
    junior_counter = 0
    
    # list for Masters players
    player_list = []
    
    for i in range(len(find_list)): # loop through players (i.e. table rows)
        player_info = find_list[i].find_all('td') # get player data from the row (i.e. table element)
        
        # check player division
        if 'Masters' in player_info[4]:
            master_counter += 1
        elif 'Senior' in player_info[4]:
            senior_counter += 1
            continue
        elif 'Junior' in player_info[4]:
            junior_counter += 1
            continue
    
        # continue gathering information for Masters players only
        player_name = player_info[1].text + " " + player_info[2].text.strip()
    
        player_list.append(Player(i, player_name, "", -1)) # player.id will correspond to i in this loop (i.e. player number including JR/SR)

    return player_list, master_counter, senior_counter, junior_counter

def ExportData(player_list, filename):
    data_list = []
    for player in player_list:
        temp = [player.id, player.name, player.decklist_link, player.classification, player.CP, player.Day2,\
                player.round_data, player.score, player.points,\
                player.decklist, player.pokemonlist, player.archetype, player.variant]
        data_list.append(temp)
    
    dataframe = pd.DataFrame(data_list, columns=['ID', 'Name', 'Link', 'Classification', 'CP', 'Day 2',\
                                                 'Rounds', 'Score', 'Points',\
                                                 'Decklist', 'Pokemon List', 'Archetype', 'Variant'])
    dataframe.to_excel(filename)
    
def ImportData(filename):
    # could use some cleaning, especially for data types, but I am too lazy for now
    imported_data = pd.read_excel(filename)
    imported_data = imported_data.values.tolist()
    
    imported_players = []
    for player in imported_data:
        # __init__(self, player_id, name, link, classification)
        new_player = Player(int(player[1]), player[2], player[3], int(player[4]))
        new_player.CP = int(player[5])
        new_player.Day2 = bool(player[6])
        new_player.round_data = np.array(eval(player[7])).tolist()
        new_player.score = np.array(eval(player[8])).tolist()
        new_player.points = int(player[9])
        new_player.decklist = np.array(eval(player[10])).tolist()
        new_player.pokemonlist = np.array(eval(player[11])).tolist()
        new_player.archetype = player[12]
        new_player.variant = player[13]
        imported_players.append(new_player)
    return imported_players

def GetPlayersFromRow(row):
    name_1, score_1, points_1 = "", [0, 0, 0], 0
    name_2, score_2, points_2 = "", [0, 0, 0], 0

    #print(row)
    
    players = re.findall(r'([a-z A-Z \- À-ÿ ő ń ï Ł Ś Š ś š ą ě č ć Č ž Ž ř ł \. \' \’ \" \s]+)[\s \[\] A-Z]+\(', row)
    name_1 = players[0].strip()
    if len(players) > 1:
        name_2 = players[1].strip()

    # 2nd step in removing character conflicts in the entry of 'idan polak' 
    # there is a very strange thing happening with this player
    # the space after their name is not a normal space for some reason
    number = row.find('idan polak')
    if number == 0:
        print('idan polak as P1')
        name_1 = 'idan polak'
    elif number > 0:
        print('idan polak as P2')
        name_2 = 'idan polak'        

    scores = re.findall(r'\((\d)-(\d)-(\d)\)', row)
    score_1 = [int(scores[0][n]) for n in range(3)]
    if len(scores) > 1:
        score_2 = [int(scores[1][n]) for n in range(3)]

    points = re.findall(r'(\d) pts', row)
    points_1 = int(points[0])
    if len(scores) > 1:
        points_2 = int(points[1])
    
    return name_1, score_1, points_1, name_2, score_2, points_2

def UpdatePlayerRound(data, round_number, player_list, table_index, duplicate_list):
    p1, s1, pt1, p2, s2, pt2 = GetPlayersFromRow(data)
    #print(p1, s1, pt1, p2, s2, pt2)
    round = 'R' + str(round_number)

    # check to see if the name is a known mistake
    p1 = CheckNameChange(p1)
    p2 = CheckNameChange(p2)
    
    # variables to check if players were successfully found
    success_p1 = False
    success_p2 = False
    if p2 == '':
        success_p2 = True

    ### DUPLICATE CHECK ###
    ### duplicate players need to the processed separately and added manually to the data later
    ### this could probably be simplified, along with merging the treatment of P1 and P2 in this function
    
    # check to see if the name of P1 is a known duplicate
    # add it to the duplicates list
    if CheckDuplicate(p1):
        new_player = Player(-1, p1, "", -1)
        new_player.points = pt1
        new_player.score = s1
        if pt1 == 3:
            result = 'W'
        elif pt1 == 1:
            result = 'T'
        elif pt1 == 0:
            result = 'L'

        # check for byes or tardiness losses
        if p2 == "":
            if result == 'W':
                new_player.round_data[round] = ['Bye', result]
            elif result == 'L':
                new_player.round_data[round] = ['Tardiness', result]
        else:
            new_player.round_data[round] = [p2, result]

        success_p1 = True
        duplicate_list.append(new_player)
        print('Processed duplicate player (' + p1 + ') in Table ' + str(table_index))

    # check to see if the name of P2 is a known duplicate
    # add it to the duplicates list
    if CheckDuplicate(p2):
        new_player = Player(-1, p2, "", -1)
        new_player.points = pt2
        new_player.score = s2
        if pt2 == 3:
            result = 'W'
        elif pt2 == 1:
            result = 'T'
        elif pt2 == 0:
            result = 'L'

        new_player.round_data[round] = [p1, result]

        success_p2 = True
        duplicate_list.append(new_player)
        print('Processed duplicate player (' + p2 + ') in Table ' + str(table_index))

    for player in player_list:
        # take care of player 1
        if player.name.lower() == p1.lower() and not success_p1:
            difference = pt1 - player.points
            if difference == 3:
                result = 'W'
            elif difference == 1:
                result = 'T'
            elif difference == 0:
                result = 'L'
            else:
                print("Something wrong happened when determining table results")
                print("Player name: " + str(p1))
                print("Table index: " + str(table_index))
                result = 'L'
            player.points = pt1
        
            # check for byes or tardiness losses
            if p2 == "":
                if result == 'W':
                     player.round_data[round] = ['Bye', result]
                elif result == 'L':
                    player.round_data[round] = ['Tardiness', result]
            else:
                player.round_data[round] = [p2, result]
            player.score = s1
    
            success_p1 = True
            
        # take care of player 2
        elif player.name.lower() == p2.lower() and not success_p2:
            difference = pt2 - player.points
            if difference == 3:
                result = 'W'
            elif difference == 1:
                result = 'T'
            elif difference == 0:
                result = 'L'
            else:
                print("Something wrong happened when determining table results")
                print("Player name: " + str(p2))
                print("Table index: " + str(table_index))
                result = 'L'
            player.points = pt2
            player.round_data[round] = [p1, result]
            player.score = s2      
    
            success_p2 = True

    if not success_p1:
        if not CheckDQ(p1):
            print("Player 1 not found in player roster or DQ list: " + p1)
            print("Table index: " + str(table_index))
    if not success_p2:
        if not CheckDQ(p2):
            print("Player 2 not found in player roster or DQ list: " + p2)
            print("Table index: " + str(table_index))

def CheckDQ(player_name):
    DQ_list = ['Jesus Nogales', 'Robert-Jan Bos', 'Jack Cheshire', 'Zhen Dong', 'Maxence de Lussac', 'Thomas Asare', 'Junior Chala', 'Alexander Mehta',\
              'Alex Alvarez', 'Van Jones']
    if player_name in DQ_list:
        return True
    return False

def CheckNameChange(player_name):
    name_conversions = {'Ryuki Okada': 'Okada Ryuki', 'Emilia Miele': 'Luca Miele', 'Nicolas Volpi': 'Nicolas Volpi (SrLagaLaga)',\
                       'Enzo Rudy SEKKAÏ': 'Enzo  Rudy SEKKAÏ', 'Princess Basser': 'Prin Basser', 'Bradley M. Smith': 'Bradley Smith'}
    if player_name in name_conversions:
        return name_conversions[player_name]
    else:
        return player_name

def CheckDuplicate(player_name):
    duplicates = ['Maxwell Johnson', 'James Taylor', 'Thomas Jones', 'Matthew Smith', 'Sammy Allen', 'Bradley Smith']
    if player_name in duplicates:
        return True
    return False

# %%
# webpage of tournament roster
soup_roster = GetWebpage("https://rk9.gg/roster/EU01wICdQN8zZclF7NTW")

# %%
### Scrap roster data ###
player_list, master_counter, senior_counter, junior_counter = GetPlayerData(soup_roster)

print("Tournament data retrieved!")
print("---------------------------------")

print("Master players: " + str(master_counter))
print("Senior players: " + str(senior_counter))
print("Junior players: " + str(junior_counter))
print("Total players: " + str(master_counter + senior_counter + junior_counter))
print("---------------------------------")
# Out:
# Tournament data retrieved!
# ---------------------------------
# Master players: 3354
# Senior players: 327
# Junior players: 279
# Total players: 3960
# ---------------------------------

# %%
# 1st step in removing character conflicts in the entry of 'idan polak' 
for player in player_list:
    if 'idan polak' in player.name:
        player.name = 'idan polak'
        print("idan polak taken care of")
# Out:
# idan polak taken care of

# %%
####################### DO NOT USE UNLESS SCRAPPING WAS JUST DONE #######################
### Export player list ###
# this is so the next sections can be run without running the scrapping all over again

filename = "Tournament data - EUIC2025/PlayerList_roster.xlsx"

ExportData(player_list, filename) # Export to excel
#########################################################################################

# %%
### Import saved data ###
filename = "Tournament data - EUIC2025/PlayerList_roster.xlsx"
# there are some complications with importing since all imports are strings and some columns contain other things 
# should clean this up later, but for now the decklist is all that matters
player_list = ImportData(filename) 

# create list of Player instances for the duplicates
# these will have to be manually taken care of at the end
duplicate_list = []

print(player_list[0].name)
print(player_list[0].round_data)
print(player_list[0].score)
print(player_list[0].points)
print(player_list[0].archetype)
print(player_list[0].variant)
# Out:
# Alejandro Chacon
# {'R1': ['Jane Doe', 'W']}
# [0, 0, 0]
# 0
# Mew VMAX
# Lost Kyogre

# %%
# webpage of tournament pairings
soup_pairings = GetWebpage("https://rk9.gg/pairings/EU01wICdQN8zZclF7NTW?pod=2&rnd=1") # pod=2&rnd=2 etc.

# %%
match_list = soup_pairings.find_all('div', class_="row row-cols-3 match no-gutter complete")

#p1, s1, pt1, p2, s2, pt2 = GetPlayersFromRow(match_list[13].text)
#print(p1, s1, pt1, p2, s2, pt2)

for i in range(len(match_list)):
    UpdatePlayerRound(match_list[i].text, 1, player_list, i, duplicate_list) 

filename = "Tournament data - EUIC2025/PlayerList_rounds.xlsx"
ExportData(player_list, filename) # Export to excel
filename = "Tournament data - EUIC2025/PlayerList_dups.xlsx"
ExportData(duplicate_list, filename) # Export duplicates to excel
# Out:
# Processed duplicate player (Sammy Allen) in Table 133
# Processed duplicate player (Maxwell Johnson) in Table 173
# Processed duplicate player (Maxwell Johnson) in Table 187
# Processed duplicate player (James Taylor) in Table 774
# Processed duplicate player (Bradley Smith) in Table 850
# Processed duplicate player (Matthew Smith) in Table 1049
# Processed duplicate player (Thomas Jones) in Table 1102
# idan polak as P1
# Processed duplicate player (Thomas Jones) in Table 1167
# Processed duplicate player (Matthew Smith) in Table 1214
# Processed duplicate player (James Taylor) in Table 1393
# Processed duplicate player (Sammy Allen) in Table 1433
# Processed duplicate player (Bradley Smith) in Table 1621

# %%
row = 'idan polak‬‏ [IL] (0-1-0) 0 pts  Table 1531 Ryan Pang [UK] (1-0-0) 3 pts '
#row = 'Samuel Collis [UK] (1-0-0) 3 pts  Table 1530 Peter Stone [ZA] (0-1-0) 0 pts '
#row = 'Samuel Collis‬‏ [UK] (0-1-0) 0 pts  Table 1531 Ryan Pang [UK] (1-0-0) 3 pts '
#row = match_list[1139].text
print(row)

players = re.findall(r'([a-z A-Z \s]+)[\s \[\] A-Z]+\(', row)
#players = re.findall(r'([a-z A-Z \- À-ÿ ő ï ń Ł Ś Š ś š ą ě č ć Č ž Ž ř ł \. \' \’ \" \s]+)[\s \[\] A-Z]+\(', row)
print(players)
  
name_1 = players[0].strip()
if len(players) > 1:
    name_2 = players[1].strip()

scores = re.findall(r'\((\d)-(\d)-(\d)\)', row)
points = re.findall(r'(\d) pts', row)

print(scores)
print(points)
# Out:
# idan polak‬‏ [IL] (0-1-0) 0 pts  Table 1531 Ryan Pang [UK] (1-0-0) 3 pts
# [' ', ' Ryan Pang ']
# [('0', '1', '0'), ('1', '0', '0')]
# ['0', '3']

# %%
# still problematic players
# Wayne Jones - in roster but not in round 1
# Nick Alvarez - in roster but not in round 1
# Jesus Alejandro Nogales Verdesca - in roster but not in round 1
